# %%
import re

# %%
def temp_norm(input) :
    temp = re.search("[0-9]+(\.*[0-9]+)?( *[a-z]*)?", input)
    print(temp)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# /tmp/ipykernel_159714/2425918910.py:2: SyntaxWarning: invalid escape sequence '\.'
#   temp = re.search("[0-9]+(\.*[0-9]+)?( *[a-z]*)?", input)

# %%
input = "310k"
temp_norm(input)
# Out:
# <re.Match object; span=(0, 4), match='310k'>
